# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjanaBabu/Datasciencelab/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
xpoints=np.array([10,11,12,13,14,15]).reshape(-1,1)
ypoints=np.array([53,52,60,63,65,67])

# %%
linreg=LinearRegression()
linreg.fit(xpoints,ypoints)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(xpoints)

# %%
plt.scatter(xpoints,ypoints)
plt.plot(xpoints,y_pred)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
print("coeffient:",linreg.coef_)
print("intercept:",linreg.intercept_)
# Out:
# coeffient: [4.22857143]
# intercept: 8.809523809523803

# %%
y_new = linreg.predict(xpoints)
print(y_new)
# Out:
# [52.  55.2 58.4 61.6 64.8 68. ]

# %%
linreg.score(xpoints, ypoints)
# Out:
# 0.9142857142857144

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
xpoints=np.array([10,11,12,13,14,15]).reshape(-1,1)
ypoints=np.array([53,52,60,63,65,67])
linreg=LinearRegression()
linreg.fit(xpoints,ypoints)
y_pred=linreg.predict(xpoints)
plt.scatter(xpoints,ypoints)
plt.plot(xpoints,y_pred)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
print("coeffient:",linreg.coef_)
print("intercept:",linreg.intercept_)
y_new = linreg.predict(xpoints)
print(y_new)
linreg.score(xpoints, ypoints)
# Out:
# coeffient: [3.2]
# intercept: 20.0
# [52.  55.2 58.4 61.6 64.8 68. ]
# 0.9142857142857144

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
# load dataset and sort as train and test data
data=load_iris()
x,y=data.data,data.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=2)

# %%
# fit data using object
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# calculate score
linreg.score(x_test,y_test)
# Out:
# 0.9024199030249113

# %%
linreg.predict(x_test)
# Out:
# array([ 1.27245167,  1.75995343,  1.47774158, -0.01656408, -0.14805657,
#        -0.08868801,  1.00511736, -0.09793416,  0.89507945, -0.15762945,
#         1.73429632,  1.72407856,  1.28492971,  1.11948831, -0.05159015,
#         1.81026251,  1.6900241 ,  1.16970138, -0.01462955,  1.69656129,
#         1.58568327, -0.1054257 ,  1.88245212,  1.56717371,  1.39977518,
#         0.07830408,  1.32977244,  2.00795533,  0.92427793,  1.54405518])

# %%
plt.plot(x_test,y_test)
# Out:
# [<matplotlib.lines.Line2D at 0x7fe9cbf91250>,
#  <matplotlib.lines.Line2D at 0x7fe9cbf91490>,
#  <matplotlib.lines.Line2D at 0x7fe9cbf91650>,
#  <matplotlib.lines.Line2D at 0x7fe9cbf91810>]
